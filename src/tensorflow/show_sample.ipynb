# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import datetime
from model import create_model
from dataset import Dataset
# Out:
# 2023-06-26 02:09:45.109728: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 02:09:45.569075: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
ds = Dataset(1000, 1000, 1000)
ds_train, ds_val, ds_test = ds.get_sets()

sample = ds_test.take(16)

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(6,6))

# show sample before preprocess
for i, (image, label) in enumerate(sample):
    axs[i//4, i%4].imshow(image, cmap=plt.cm.gray)
    
plt.tight_layout()
plt.show()
# Out:
# Found 1370 files belonging to 62 classes.
# Found 128 files belonging to 62 classes.
# Found 124 files belonging to 62 classes.
# 2023-06-26 02:09:46.498977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-26 02:09:46.535944: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
