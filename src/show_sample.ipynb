# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import datetime
from model import create_model
from dataset import get_custom_sets, get_emnist_sets, get_sets
# Out:
# 2023-05-24 17:18:32.854327: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-24 17:18:33.277857: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
ds_train, ds_val, ds_test = get_custom_sets()

sample = ds_train.take(2)

# show sample before preprocess
for image, label in sample:
    print(label)
    plt.imshow(image, cmap='gray')
    plt.ylabel("Pixel (px)")
    plt.xlabel("Pixel (px)")
    plt.show()
# Out:
# Found 1370 files belonging to 62 classes.
# Found 128 files belonging to 62 classes.
# Found 128 files belonging to 62 classes.
# Custom Set: Train size: 1370, Val size: 128, Test size: 128
# tf.Tensor(53, shape=(), dtype=int64)
# 2023-05-24 17:18:42.677546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [1370]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-24 17:18:42.677732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [1370]
# 	 [[{{node Placeholder/_0}}]]
# tf.Tensor(18, shape=(), dtype=int64)
